# %% [markdown]
# <a href="https://colab.research.google.com/github/angelo-chu/python/blob/main/csv_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Merge

# %%
import pandas as pd
def edit_csv(df):
    df['price'] = df['price'].astype(int)
    # ... other data type changes

    df.to_csv('/content/drive/My Drive/Coding/housing.csv', index=False)

# Example usage:
df = pd.read_csv('/content/drive/My Drive/Coding/housing.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-179a22d32c07> in <cell line: 9>()
#       7
#       8 # Example usage:
# ----> 9 df = pd.read_csv('/content/drive/My Drive/Coding/housing.csv')
#      10 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

df = pd.read_csv('/content/drive/My Drive/Coding/housing.csv')
df.head()

import os
import subprocess

# Get current working directory
directory = "/content/drive/My Drive/Coding"

# Get today's date in YYYYMMDD format
todays_date = subprocess.check_output(["date", "+%Y%m%d"]).decode().strip()

# Iterate through CSV files in the working directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        old_name = os.path.join(directory, filename)
        new_name = os.path.join(directory, f"{os.path.splitext(filename)[0]}_formatted_{todays_date}.csv")
        os.rename(old_name, new_name)

# Get current working directory
directory = "/content/drive/My Drive/Coding"

# Get today's date in YYYYMMDD format
todays_date = subprocess.check_output(["date", "+%Y%m%d"]).decode().strip()

# Iterate through CSV files in the working directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        old_name = os.path.join(directory, filename)
        new_name = os.path.join(directory, f"housing.csv")
        os.rename(old_name, new_name)

# %%
import pandas as pd

# Define the paths to the CSV files
file1 = '/content/drive/My Drive/Coding/housing.csv'
file2 = '/content/drive/My Drive/Coding/housing2.csv'

# Read the CSV files into DataFrames
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# Concatenate the DataFrames
df = pd.concat([df1, df2], ignore_index=True)

# Print the DataFrame
df.tail()

df.to_csv('/content/drive/My Drive/Coding/merged_housing.csv', index=False)
df3 = pd.read_csv('/content/drive/My Drive/Coding/merged_housing.csv')
df3.tail()

# %% [markdown]
# # Clear a column in multiple csv files

# %%
import pandas as pd
import glob
import os

# Mount Google Drive (if your files are on Drive)
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Set the working directory to where your files are located
os.chdir('/content/drive/My Drive/Coding/Clear column')

# Get a list of all CSV files in the directory
file_list = glob.glob("*.csv")
file_list

# %%
# Process each file
for filename in file_list:
    df = pd.read_csv(filename)

    # Clear the values in the "Customer external address" column
    df["Address"] = ""

    # Save the modified DataFrame back to the same CSV file
    df.to_csv(filename, index=False)

print("address column cleared in all files!")

# %% [markdown]
# # Analyze sales data
# - [sales data sample](https://excelbianalytics.com/wp/downloads-18-sample-csv-files-data-sets-for-testing-sales/)

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/Coding/csv handling/Data/sales.csv')
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID Ship Date  Units Sold  \
# 0       Offline              H    5/28/10  669165933   6/27/10        9925
# 1        Online              C    8/22/12  963881480   9/15/12        2804
# 2       Offline              L     5/2/14  341417157    5/8/14        1779
# 3        Online              C    6/20/14  514321792    7/5/14        8102
# 4       Offline              L     2/1/13  115456712    2/6/13        5062
#
# ...

# %%
df.set_index('Region')

#Calculate total revenue by region
rev_by_region = df.groupby(['Region'])['Total Revenue'].sum()
rev_by_region.plot.barh(title = "revenue by region", rot = 0)
# Out:
# <Axes: title={'center': 'revenue by region'}, ylabel='Region'>

# %%
#Filter revenue > 2.5 million dollars
large_revenue = df[df['Total Revenue'] > 2500000]
large_revenue.shape[0]
large_revenue
# Out:
#                                Region       Country        Item Type  \
# 0               Australia and Oceania        Tuvalu        Baby Food
# 4                  Sub-Saharan Africa        Rwanda  Office Supplies
# 6                  Sub-Saharan Africa        Angola        Household
# 13  Central America and the Caribbean      Honduras        Household
# 16                               Asia     Sri Lanka        Cosmetics
# 18                               Asia  Turkmenistan        Household
# 30                             Europe   Switzerland        Cosmetics
# 33                               Asia       Myanmar        Household
# 38                               Asia        Brunei  Office Supplies
# 39                             Europe      Bulgaria  Office Supplies
# 41       Middle East and North Africa    Azerbaijan        Cosmetics
# 46                             Europe       Iceland        Cosmetics
# 59                 Sub-Saharan Africa      Djibouti        Cosmetics
# ...

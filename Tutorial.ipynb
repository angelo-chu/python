# %% [markdown]
# <a href="https://colab.research.google.com/github/angelo-chu/python/blob/main/Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
people = {
    "first": ["Corey", "John", "Alice"],
    "last": ["Schafer", "Doe", "Smith"],
    "email": ["abc@gmail.com", "johndoe@gmail.com", "alice.smith@example.com"]
}

# %%
import pandas as pd

df = pd.DataFrame(people)
df.loc[0:2, ['email']]
# Out:
#                      email
# 0            abc@gmail.com
# 1        johndoe@gmail.com
# 2  alice.smith@example.com

# %%
df.iloc[[0, 1], [0, 1, 2]]
# Out:
#    first     last              email
# 0  Corey  Schafer      abc@gmail.com
# 1   John      Doe  johndoe@gmail.com

# %%
df.loc[0:2, ['email', 'first']]
# Out:
#                      email  first
# 0            abc@gmail.com  Corey
# 1        johndoe@gmail.com   John
# 2  alice.smith@example.com  Alice

# %%
df['email'].value_counts()
# Out:
# abc@gmail.com              1
# johndoe@gmail.com          1
# alice.smith@example.com    1
# Name: email, dtype: int64

# %%
df = pd.DataFrame(people)
df.loc[0:2, ['email']]
df
# Out:
#    first     last                    email
# 0  Corey  Schafer            abc@gmail.com
# 1   John      Doe        johndoe@gmail.com
# 2  Alice    Smith  alice.smith@example.com

# %%
#set email as index
df.set_index('email')
#modify on the existing dataframe
df.set_index('email', inplace = True)
# show result
df
# Out:
#                          first     last
# email
# abc@gmail.com            Corey  Schafer
# johndoe@gmail.com         John      Doe
# alice.smith@example.com  Alice    Smith

# %%
# show index values
df.index
# Out:
# Index(['abc@gmail.com', 'johndoe@gmail.com', 'alice.smith@example.com'], dtype='object', name='email')

# %% [markdown]
# **Read external CSV**

# %%
from google.colab import drive

import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/Coding/survey_results_public.csv')
schema_df =  pd.read_csv('/content/drive/My Drive/Coding/survey_results_schema.csv')

# %%
pd.set_option('display.max_rows', 85)
pd.set_option('display.max_columns', 85)

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.loc[0]
# Out:
# ResponseId                                           1
# Q120                                           I agree
# MainBranch                               None of these
# Age                                    18-24 years old
# Employment                                         NaN
# RemoteWork                                         NaN
# CodingActivities                                   NaN
# EdLevel                                            NaN
# LearnCode                                          NaN
# LearnCodeOnline                                    NaN
# LearnCodeCoursesCert                               NaN
# YearsCode                                          NaN
# YearsCodePro                                       NaN
# DevType                                            NaN
# OrgSize                                            NaN
# PurchaseInfluence                                  NaN
# TechList                                           NaN
# ...

# %%
df['ResponseId']
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 89179    89180
# 89180    89181
# 89181    89182
# 89182    89183
# 89183    89184
# Name: ResponseId, Length: 89184, dtype: int64
